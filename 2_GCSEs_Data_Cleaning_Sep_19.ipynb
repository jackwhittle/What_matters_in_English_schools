# %% [markdown]
# # <font color = 'green'>Purpose of this Notebook: to clean the raw GCSE data and create a dataset for use in modeling</font>

# %% [markdown]
# ## Index
#
# <a href='#nb_setup'>Notebook Set Up</a><br />
# 1)  <a href='#1'>Create a DataFrame with 2017-18 (all base) data</a><br />
# 2)  <a href='#2'>Remove Special Schools and rows of summary data</a><br />
# 3)  <a href='#3'>Remove invalid values for target y (Field: P8MEA)</a><br />
# 4)  <a href='#4'>Examine number of Nulls / NaNs per column and row, and format the target variable correctly</a><br />
# 5)  <a href='#5'>Create a table to show which data in which columns need to be cleaned</a><br />
# 6)  <a href='#6'>Decide how to handle remaining non-numeric data</a><br />
# 7)  <a href='#7'>Action the decisions made in 6) above, to make data modelable</a><br />
# 8)  <a href='#8'>Convert all relevant columns to floats</a><br />
# 9)  <a href='#9'>Export final (base) dataset</a><br />
#
# <br />

# %% [markdown]
# <a id='nb_setup'></a>

# %% [markdown]
# # <font color='blue'>Notebook Set Up (import modules and data)</font>

# %%
# import the libraries and modules that will be needed

import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# added additional modules that will be needed
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from pandas import read_csv
import csv

plt.style.use('ggplot')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# import base data

df = read_csv('data_files/england_ks4final17_18.csv')
df_ks4_meta = read_csv('data_files/_ks4final_meta.csv')
# Out:
# /Users/jacktyler-whittle/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5673 entries, 0 to 5672
# Columns: 496 entries, RECTYPE to P8_BANDING
# dtypes: float64(12), int64(1), object(483)
# memory usage: 21.5+ MB

# %%
# Summary of school types (1=mainstream school; 2=special school; 4=local authority; 5=National (all schools); 7=National (maintained schools))

df['RECTYPE'].value_counts()
# Out:
# 1    4328
# 2    1191
# 4     152
# 7       1
# 5       1
# Name: RECTYPE, dtype: int64

# %% [markdown]
# <a id='1'></a>

# %% [markdown]
# # <font color='blue'>1) Create a DataFrame with 2017-18 (all base) data</font>
# Dataset goes from 496 to 279 columns

# %% [markdown]
# - Set up DataFrame for 2017-18 data (name: df2)
# - **Decisions**<br />
#    1) To avoid autocorrelation, exclude data that is duplicating data represented already, but in a slightly different manner.  e.g.:
#      - Exclude columns containing numbers which are represented as percentages in another column (e.g. exclude
#     'Number of boys at the end of key stage 4' and include only 'Percentage of pupils at the end of key stage 4 who are boys')<br />
#      - Exclude data showing percentage of girls, and include only data showing percentage of boys, as one can be directly inferred from the other<br />
#
#   2) Exclude columns containing upper and lower confidence intervals for measures<br />
#    3) Exclude data on previous years, as this model was to explain variation within the year's results (time series analysis will be covered in a future phase of this project).<br />
#
# **Note**: all columns, with their descriptions, are noted in ['GCSEs_Key_Meta_Sep-19.xls']('GCSEs_Key_Meta_Sep-19.xls').  The columns highlighted in green in 'Include in Base Model' (column J) are those which were included in the base model below.

# %%
# Create DataFrame

df2 = df[[
'RECTYPE',
'LEA',
'ESTAB',
'URN',
'SCHNAME',
'SCHNAME_AC',
'PCODE',
'ICLOSE',
'NFTYPE',
'RELDENOM',
'ADMPOL',
'ADMPOL_2017',
'EGENDER',
'FEEDER',
'TABKS2',
'TAB1618',
'TOTPUPS',
'NUMBOYS',
'NUMGIRLS',
'TPUP',
'PBPUP',
'KS2APS',
'PTPRIORLO',
'PTPRIORAV',
'PTPRIORHI',
'PTFSM6CLA1A',
'PTNOTFSM6CLA1A',
'PTEALGRP2',
'PTEALGRP1',
'PTEALGRP3',
'PTNMOB',
'PSENSE4',
'PSENAPK4',
'ATT8SCR',
'ATT8SCRENG',
'ATT8SCRMAT',
'ATT8SCREBAC',
'ATT8SCROPEN',
'ATT8SCROPENG',
'ATT8SCROPENNG',
'AVGEBACFILL',
'AVGOPENFILL',
'P8PUP',
'TP8ADJ',
'P8MEACOV',
'P8MEA',
'P8CILOW',
'P8CIUPP',
'P8MEA_ORIG',
'P8MEAENG',
'P8MEAMAT',
'P8MEAEBAC',
'P8MEAOPEN',
'PTL2BASICS_94',
'PTL2BASICS_95',
'TOTEBACCAPS',
'EBACCAPS',
'EBACCAPS_FSM6CLA1A',
'EBACCAPS_NFSM6CLA1A',
'EBACCAPS_LO',
'EBACCAPS_AV',
'EBACCAPS_HI',
'EBACCAPS_EAL',
'EBACCAPS_GIRLS',
'EBACCAPS_NMOB',
'PTEBACC_E_PTQ_EE',
'PTEBACC_94',
'PTEBACC_95',
'PTEBACENG_E_PTQ_EE',
'PTEBACMAT_E_PTQ_EE',
'PTEBAC2SCI_E_PTQ_EE',
'PTEBACHUM_E_PTQ_EE',
'PTEBACLAN_E_PTQ_EE',
'PTEBACENG_94',
'PTEBACENG_95',
'PTEBACMAT_94',
'PTEBACMAT_95',
'PTEBAC2SCI_94',
'PTEBAC2SCI_95',
'PTEBACHUM_94',
'PTEBACHUM_95',
'PTEBACLAN_94',
'PTEBACLAN_95',
'SCIVACOV_PTQ_EE',
'HUMVACOV_PTQ_EE',
'LANVACOV_PTQ_EE',
'SCIVAMEA_PTQ_EE',
'HUMVAMEA_PTQ_EE',
'LANVAMEA_PTQ_EE',
'TEBACENG_94',
'TEBACENG_95',
'TEBACMAT_94',
'TEBACMAT_95',
'TEBAC2SCI_94',
'TEBAC2SCI_95',
'TEBACHUM_94',
'TEBACHUM_95',
'TEBACLAN_94',
'TEBACLAN_95',
'PTEBACC91',
'PTEBACENG91',
'PTEBACMAT91',
'PTEBAC2SCI91',
'PTEBACHUM91',
'PTEBACLAN91',
'ATT8SCR_FSM6CLA1A',
'P8PUP_FSM6CLA1A',
'TP8ADJ_FSM6CLA1A',
'P8MEA_FSM6CLA1A',
'P8MEA_FSM6CLA1A_ORIG',
'ATT8SCR_NFSM6CLA1A',
'P8PUP_NFSM6CLA1A',
'TP8ADJ_NFSM6CLA1A',
'P8MEA_NFSM6CLA1A',
'P8MEA_NFSM6CLA1A_ORIG',
'ATT8SCRENG_FSM6CLA1A',
'P8MEAENG_FSM6CLA1A',
'ATT8SCRMAT_FSM6CLA1A',
'P8MEAMAT_FSM6CLA1A',
'ATT8SCREBAC_FSM6CLA1A',
'P8MEAEBAC_FSM6CLA1A',
'ATT8SCROPEN_FSM6CLA1A',
'P8MEAOPEN_FSM6CLA1A',
'ATT8SCRENG_NFSM6CLA1A',
'P8MEAENG_NFSM6CLA1A',
'ATT8SCRMAT_NFSM6CLA1A',
'P8MEAMAT_NFSM6CLA1A',
'ATT8SCREBAC_NFSM6CLA1A',
'P8MEAEBAC_NFSM6CLA1A',
'ATT8SCROPEN_NFSM6CLA1A',
'P8MEAOPEN_NFSM6CLA1A',
'ATT8SCROPENG_FSM6CLA1A',
'ATT8SCROPENNG_FSM6CLA1A',
'ATT8SCROPENG_NFSM6CLA1A',
'ATT8SCROPENNG_NFSM6CLA1A',
'DIFFN_ATT8',
'DIFFN_P8MEA',
'ATT8SCR_LO',
'P8PUP_LO',
'TP8ADJ_LO',
'P8MEA_LO',
'P8MEA_LO_ORIG',
'ATT8SCR_AV',
'P8PUP_AV',
'TP8ADJ_AV',
'P8MEA_AV',
'P8MEA_AV_ORIG',
'ATT8SCR_HI',
'P8PUP_HI',
'TP8ADJ_HI',
'P8MEA_HI',
'P8MEA_HI_ORIG',
'ATT8SCR_EAL',
'ATT8SCRENG_EAL',
'ATT8SCRMAT_EAL',
'ATT8SCREBAC_EAL',
'ATT8SCROPEN_EAL',
'ATT8SCROPENG_EAL',
'ATT8SCROPENNG_EAL',
'P8PUP_EAL',
'TP8ADJ_EAL',
'P8MEA_EAL',
'P8MEA_EAL_ORIG',
'ATT8SCR_GIRLS',
'ATT8SCRENG_GIRLS',
'ATT8SCRMAT_GIRLS',
'ATT8SCREBAC_GIRLS',
'ATT8SCROPEN_GIRLS',
'ATT8SCROPENG_GIRLS',
'ATT8SCROPENNG_GIRLS',
'P8PUP_GIRLS',
'TP8ADJ_GIRLS',
'P8MEA_GIRLS',
'P8MEA_GIRLS_ORIG',
'ATT8SCR_BOYS',
'ATT8SCRENG_BOYS',
'ATT8SCRMAT_BOYS',
'ATT8SCREBAC_BOYS',
'ATT8SCROPEN_BOYS',
'ATT8SCROPENG_BOYS',
'ATT8SCROPENNG_BOYS',
'P8PUP_BOYS',
'TP8ADJ_BOYS',
'P8MEA_BOYS',
'P8MEA_BOYS_ORIG',
'ATT8SCR_NMOB',
'ATT8SCRENG_NMOB',
'ATT8SCRMAT_NMOB',
'ATT8SCREBAC_NMOB',
'ATT8SCROPEN_NMOB',
'ATT8SCROPENG_NMOB',
'ATT8SCROPENNG_NMOB',
'P8PUP_NMOB',
'TP8ADJ_NMOB',
'P8MEA_NMOB',
'P8MEA_NMOB_ORIG',
'TEBACC_ELO_PTQ_EE',
'PTEBACC_ELO_PTQ_EE',
'PTEBACCLO_94',
'PTEBACCLO_95',
'TEBACC_EAV_PTQ_EE',
'PTEBACC_EAV_PTQ_EE',
'PTEBACCAV_94',
'PTEBACCAV_95',
'TEBACC_EHI_PTQ_EE',
'PTEBACC_EHI_PTQ_EE',
'PTEBACCHI_94',
'PTEBACCHI_95',
'PTEBACC_EFSM6CLA1A_PTQ_EE',
'PTEBACC_ENFSM6CLA1A_PTQ_EE',
'PTEBACC_94_FSM6CLA1A',
'PTEBACC_95_FSM6CLA1A',
'PTEBACC_94_NFSM6CLA1A',
'PTEBACC_95_NFSM6CLA1A',
'SCIVAMEA_LO_PTQ_EE',
'SCIVAMEA_AV_PTQ_EE',
'SCIVAMEA_HI_PTQ_EE',
'SCIVAMEA_FSM6CLA1A_PTQ_EE',
'SCIVAMEA_NFSM6CLA1A_PTQ_EE',
'HUMVAMEA_LO_PTQ_EE',
'HUMVAMEA_AV_PTQ_EE',
'HUMVAMEA_HI_PTQ_EE',
'HUMVAMEA_FSM6CLA1A_PTQ_EE',
'HUMVAMEA_NFSM6CLA1A_PTQ_EE',
'LANVAMEA_LO_PTQ_EE',
'LANVAMEA_AV_PTQ_EE',
'LANVAMEA_HI_PTQ_EE',
'LANVAMEA_FSM6CLA1A_PTQ_EE',
'LANVAMEA_NFSM6CLA1A_PTQ_EE',
'PTEBACC_94_17',
'PTEBACC_95_17',
'PBEBACC_E_PTQ_EE',
'PBEBACC_94',
'PBEBACC_95',
'PGEBACC_E_PTQ_EE',
'PGEBACC_94',
'PGEBACC_95',
'PTEBACC_ENMOB_PTQ_EE',
'PTEBACCNMOB_94',
'PTEBACCNMOB_95',
'PTEBACC_EEAL_PTQ_EE',
'PTEBACCEAL_94',
'PTEBACCEAL_95',
'PT5EM_94',
'PT5EM_94_18',
'PTANYQ_PTQ_EE',
'PTFSM6CLA1ABASICS_94',
'PTNOTFSM6CLA1ABASICS_94',
'PTBASICSLO_94',
'PTBASICSAV_94',
'PTBASICSHI_94',
'PBL2BASICS_94',
'PGL2BASICS_94',
'PTL2BASICSEAL_94',
'PTL2BASICSNMOB_94',
'PTFSM6CLA1ABASICS_95',
'PTNOTFSM6CLA1ABASICS_95',
'PTBASICSLO_95',
'PTBASICSAV_95',
'PTBASICSHI_95',
'PBL2BASICS_95',
'PGL2BASICS_95',
'PTL2BASICSEAL_95',
'PTL2BASICSNMOB_95',
'PTmultiLan_E',
'PTtripleSci_E',
'TAVENT_E_3NG_PTQ_EE',
'TAVENT_E_3NG_LO_PTQ_EE',
'TAVENT_E_3NG_AV_PTQ_EE',
'TAVENT_E_3NG_HI_PTQ_EE',
'TAVENT_E_3NG_FSM6CLA1A_PTQ_EE',
'TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE',
'TAVENT_G_PTQ_EE',
'TAVENT_GLO_PTQ_EE',
'TAVENT_GAV_PTQ_EE',
'TAVENT_GHI_PTQ_EE',
'TAVENT_GFSM6CLA1A_PTQ_EE',
'TAVENT_GNFSM6CLA1A_PTQ_EE',
'P8_BANDING',
]]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5673 entries, 0 to 5672
# Columns: 279 entries, RECTYPE to P8_BANDING
# dtypes: float64(8), int64(1), object(270)
# memory usage: 12.1+ MB

# %%
df2.head(3)
# Out:
#    RECTYPE    LEA   ESTAB       URN                 SCHNAME SCHNAME_AC  \
# 0        1  202.0  4104.0  100049.0       Haverstock School        NaN
# 1        1  202.0  4166.0  100050.0  Parliament Hill School        NaN
# 2        1  210.0  4005.0  145313.0         Bacon's College        NaN
#
#       PCODE  ICLOSE NFTYPE           RELDENOM  ... TAVENT_E_3NG_HI_PTQ_EE  \
# 0   NW3 2BQ     0.0     CY     Does not apply  ...                    7.7
# 1   NW5 1RL     0.0     CY     Does not apply  ...                    8.8
# 2  SE16 6AT     0.0     AC  Church of England  ...                    NaN
#
#   TAVENT_E_3NG_FSM6CLA1A_PTQ_EE TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE  \
# 0                           7.2                            7.4
# 1                           8.6                            8.4
# 2                           NaN                            NaN
#
#    TAVENT_G_PTQ_EE  TAVENT_GLO_PTQ_EE  TAVENT_GAV_PTQ_EE TAVENT_GHI_PTQ_EE  \
# 0              7.1                6.3                6.9               7.7
# 1              8.4                6.9                8.1               8.7
# 2              NaN                NaN                NaN               NaN
#
#   TAVENT_GFSM6CLA1A_PTQ_EE TAVENT_GNFSM6CLA1A_PTQ_EE  P8_BANDING
# 0                        7                       7.3           3
# 1                      8.5                       8.3           1
# 2                      NaN                       NaN         NaN
#
# [3 rows x 279 columns]

# %% [markdown]
# ## <font color='green'>Summary stats for all England</font>

# %%
# National Data - all schools (5430) and maintained schools (5431)

df2.loc[5430:5431, ('P8MEA', 'P8MEA_ORIG', 'ATT8SCR','TAVENT_E_3NG_PTQ_EE','TAVENT_G_PTQ_EE','TOTPUPS','TPUP', 'PT5EM_94')]
# Out:
#       P8MEA P8MEA_ORIG ATT8SCR TAVENT_E_3NG_PTQ_EE TAVENT_G_PTQ_EE  TOTPUPS  \
# 5430    NaN        NaN    44.5                 7.8             7.4  3709343
# 5431  -0.02      -0.03    46.5                 8.3             7.8  3290097
#
#           TPUP PT5EM_94
# 5430  583615.0   55.50%
# 5431  523636.0   60.10%

# %%
# Average attainment points per average number of GCSEs taken:
    
# All schools:
print("All Schools: "+ str(44.5/7.4))

# All maintained schools:
print("All Maintained Schools: "+ str(46.5/7.8))
# Out:
# All Schools: 6.013513513513513
# All Maintained Schools: 5.961538461538462

# %% [markdown]
# <a id='2'></a>

# %% [markdown]
# # <font color='blue'>2) Remove Special Schools and rows of summary data</blue>
# Dataset goes from 5,673 entries (rows) to 4,328 schools to model (rows)

# %% [markdown]
# **Decision**: remove Special Schools as they are by definition different from other secondary schools; also remove all rows of data that are summary data (and not data for specific schools)

# %%
# Remove the special needs schools (RECTYPE 1)

df2['RECTYPE'].value_counts()
# Out:
# 1    4328
# 2    1191
# 4     152
# 7       1
# 5       1
# Name: RECTYPE, dtype: int64

# %%
df3 = df2[df2['RECTYPE'] == 1]

# %%
df3['RECTYPE'].value_counts()
# Out:
# 1    4328
# Name: RECTYPE, dtype: int64

# %% [markdown]
# <a id='3'></a>

# %% [markdown]
# # <font color='blue'>3) Remove invalid values for target y (Field: P8MEA)</blue>
#
# Goes from 4,328 to 3,165 rows (schools)

# %%
# Check that the Progress 8 Banding is not provided for schools which are not reporting a Progress 8 score

df3[df3['P8MEA'].isin(['NP', 'NE', 'SUPP', 'LOWCOV', 'NEW'])]['P8_BANDING'].value_counts()
# Out:
# SUPP    4
# Name: P8_BANDING, dtype: int64

# %%
# remove invalid values for target y (P8MEA)

df4 = df3[~df3['P8MEA'].isin(['NP', 'NE', 'SUPP', 'LOWCOV', 'NEW'])]
len(df4)
# Out:
# 3393

# %%
# drop NaNs in P8MEA column (as there needs to be a target y for each school that is part of the model)
df4 = df4.dropna(subset=['P8MEA'])

# %%
# see number of schools now in dataset
len(df4)
# Out:
# 3165

# %% [markdown]
# <a id='4'></a>

# %% [markdown]
# # <font color='blue'>4) Examine number of Nulls / NaNs per column and row, and format the target variable correctly</blue>
# Dataset stays at 3,165 rows (schools)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3165 entries, 0 to 5580
# Columns: 279 entries, RECTYPE to P8_BANDING
# dtypes: float64(8), int64(1), object(270)
# memory usage: 6.8+ MB

# %% [markdown]
# ### <font color='green'>a) Number of NaNs per column and per row</font>

# %%
# Look at number of Nulls / NaNs per column

df_column_nulls = pd.DataFrame(df4.isnull().sum().sort_values(ascending=False), columns=['number_nulls'])
df_column_nulls.head()
# Out:
#               number_nulls
# SCHNAME_AC            3073
# PBPUP                  200
# ATT8SCR_BOYS           200
# P8PUP_BOYS             200
# P8MEA_BOYS             200

# %%
# Look at number of Nulls / NaNs per row

df4.isnull().sum(axis=1).sort_values(ascending=False).head(10)
# Out:
# 3305    7
# 1212    6
# 3424    6
# 3434    6
# 3433    6
# 3431    6
# 3429    6
# 3986    6
# 3423    6
# 165     6
# dtype: int64

# %% [markdown]
# ###  <font color='green'>b) Remove columns and rows with a very high volume of NaNs</font>

# %%
# remove Revised School Name (for Schools converted to Academy since Sep 2015) as it is not relevant for
# analysis of 2018 data; all other rows and columns have small enough volume of NaNs
# to see how they can be imputed

df4.drop('SCHNAME_AC', axis=1, inplace=True)

# %% [markdown]
# ###  <font color='green'>c) Format the target y column correctly</font>

# %%
# format the Target y column correctly

df4['P8MEA'] = df4['P8MEA'].astype(float)

# %% [markdown]
# <a id='5'></a>

# %% [markdown]
# # <font color='blue'>5) Create a table to show which data in which columns need to be cleaned</font>

# %%
df5 = df4.copy()

# %% [markdown]
# ### <font color='green'>a) Identify which columns (that should be floats) have the following keywords in their columns (these are words highlighted in the meta data provided as ones which are used in the file):</font>
#
# - NEW
# - NE
# - NA
# - SUPP
# - NP
# - LOWCOV

# %%
# write a function to create a DataFrame containing a list of all the columns in the base dataset, and how many
# of each text type abbreviations are being used in place of values

def item_freq_in_col(df, list_words, sort_by='total_freq'):
    '''Input: dataframe and the 'items' you want to count (in a list)
    Returns new Dataframe with:
    1) Columns from original dataframe as rows
    2) Number of NaNs per column ('# nulls')
    3) Frequency of 'items' from each column listed in a separate column per 'item'
    4) Total (sum) of all text items for that column
    5) % of rows that the text values represent
    '''
    
    df_item_freq = pd.DataFrame({'column_name':df.columns})
    
    df_item_freq['# nulls'] = [df[col].isnull().sum() for col in df.columns]
    
    for word in list_words:
        dict = {i: np.sum(df[i] == word) for i in df.columns}
        df_item_freq['# "' + word + '"'] = dict.values()
        
    df_item_freq['total_freq'] = df_item_freq.sum(axis=1)
    df_item_freq['pct_all_rows'] = df_item_freq['total_freq'].apply(lambda x: round(x/len(df)*100))
    df_item_freq.sort_values(sort_by, ascending=False, inplace=True)  
    return df_item_freq

# %%
df_item_freq = item_freq_in_col(df5,['NE','SUPP', 'NEW', 'NA', 'LOWCOV', 'NP'])
df_item_freq.head(3)
# Out:
# /Users/jacktyler-whittle/anaconda3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#             column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 223  LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 160           P8MEA_EAL        0     150      1168        0       0
# 159          TP8ADJ_EAL        0     165      1168        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 223           5       0        2587            82
# 160           0      15        1333            42
# 159           0       0        1333            42

# %% [markdown]
# ### <font color='green'>b) Add in a description of each column to help determine what to do with it</font>

# %%
# 1) review csv of column descriptions

df_ks4_meta.head(3)
# Out:
#    Column Metafile heading                               Metafile description  \
# 0       1          RECTYPE  Record type (1=mainstream school; 2=special sc...
# 1       2         ALPHAIND                           Alphabetic sorting index
# 2       3              LEA  Local authority code (see separate list of loc...
#
#   Methodology changes Null field for special schools  \
# 0                 NaN                            NaN
# 1                 NaN                            NaN
# 2                 NaN                            NaN
#
#   Null field for local authority records  \
# 0                                    NaN
# 1                                    Yes
# 2                                    NaN
#
#   Null field for National (all schools) records  \
# 0                                           NaN
# 1                                           Yes
# 2                                           Yes
#
#   Null field for National (maintained schools) records
# 0                                                NaN
# 1                                                Yes
# 2                                                Yes

# %%
# 2) rename columns to align with naming convertion used in 'df_item_freq' DataFrame above

df_ks4_meta_2 = df_ks4_meta[['Metafile heading', 'Metafile description']]
df_ks4_meta_2.columns = ['column_name', 'column_description']
df_ks4_meta_2.head(3)
# Out:
#   column_name                                 column_description
# 0     RECTYPE  Record type (1=mainstream school; 2=special sc...
# 1    ALPHAIND                           Alphabetic sorting index
# 2         LEA  Local authority code (see separate list of loc...

# %%
# 3) merge df of column descriptions with the 'df_item_freq' DataFrame (note: left_index keeps the index)

df_data_issues = pd.merge(df_item_freq, df_ks4_meta_2, on='column_name', how='left', left_index=True)
df_data_issues.head(3)
# Out:
#             column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 365  LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 256           P8MEA_EAL        0     150      1168        0       0
# 255          TP8ADJ_EAL        0     165      1168        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows  \
# 365           5       0        2587            82
# 256           0      15        1333            42
# 255           0       0        1333            42
#
#                                     column_description
# 365  English Baccalaureate Languages Value Added me...
# 256  Adjusted Progress 8 measure - pupils for whom ...
# 255  Number of pupils for whom English is an additi...

# %%
# check that there are 'Total Pupils' for all schools in the dataset

df_data_issues[df_data_issues['column_name'] == 'TOTPUPS']
# Out:
#    column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  # "LOWCOV"  \
# 25     TOTPUPS        0       0         0        0       0           0
#
#     # "NP"  total_freq  pct_all_rows                   column_description
# 25      15          15             0  Number of pupils on roll (all ages)

# %%
# number of columns containing non-numeric (unmodelable) data 

df_data_issues[df_data_issues['# "SUPP"'] > 0].count()
# Out:
# column_name           196
# # nulls               196
# # "NE"                196
# # "SUPP"              196
# # "NEW"               196
# # "NA"                196
# # "LOWCOV"            196
# # "NP"                196
# total_freq            196
# pct_all_rows          196
# column_description    196
# dtype: int64

# %%
len(df5)
# Out:
# 3165

# %% [markdown]
# <a id='6'></a>

# %% [markdown]
# # <font color='blue'>6) Decide how to handle remaining non-numeric data</font>
# To maximise number of schools and features being modeled, without compromising on quality of data

# %% [markdown]
# ### <font color='green'>a) Determine whether Boys and Girls' NaN values should be replaced with zeroes, as they represent single sex schools</font>

# %%
# of all the schools with Number of Boys as NaN, how many are Girls only schools?
# A: all of them

filtered_df = df5[df5['NUMBOYS'].isnull()]
filtered_df['EGENDER'].value_counts()
# Out:
# GIRLS    115
# Name: EGENDER, dtype: int64

# %%
# of all the schools with Number of Girls as NaN, how many are Boys only schools?
# A: all of them

filtered_df = df5[df5['NUMGIRLS'].isnull()]
filtered_df['EGENDER'].value_counts()
# Out:
# BOYS    148
# Name: EGENDER, dtype: int64

# %% [markdown]
# **DECISION**: replace NaN values with 0 for the above, and other related fields (see section 7 below)

# %% [markdown]
# ### <font color='green'>b ) Determine what to do with the 'Admissions Policy' columns</font>

# %%
df5['ADMPOL'].value_counts()
# Out:
# COMP    2864
# SEL      162
# MOD      110
# UK         2
# Name: ADMPOL, dtype: int64

# %%
df5['ADMPOL_2017'].value_counts()
# Out:
# OTHER NON SEL                 2759
# NON SEL IN HIGHLY SEL AREA     215
# SEL                            162
# Name: ADMPOL_2017, dtype: int64

# %% [markdown]
# **DECISION**: change blanks to 'OTHER NON SEL' (since 'SEL' - Selective Schools - is fully accounted for in the data (all Grammar Schools in the UK)) (see section 7 below)

# %% [markdown]
# ### <font color='green'>c) Determine how to handle values for 'Suppressed' Progress 8 Banding values</font>

# %%
# Look at the distribution of Progress 8 Banding

df5['P8_BANDING'].value_counts()

# don't need to remove the 'SUPP' rows as they have a P8MEA, so Banding can be inferred
# Out:
# 3       1126
# 4        594
# 2        512
# 1        411
# 5        377
# SUPP     145
# Name: P8_BANDING, dtype: int64

# %%
# Look at schools with Progress 8 Banding 'Suppressed' (Value: 'SUPP'), which indicates that
# a school or college's figures have been suppressed because there are 5 or fewer pupils in the cohort

df5a = df5[df5['P8_BANDING'] == 'SUPP']

df5b = df5a.loc[:, ('URN','P8MEA', 'P8_BANDING', 'LEA', 'TPUP', 'P8CILOW', 'P8CIUPP')].sort_values('TPUP')
df5b.head()
# Out:
#            URN  P8MEA P8_BANDING    LEA  TPUP P8CILOW P8CIUPP
# 3421  139895.0  -2.99       SUPP  884.0  10.0   -3.77   -2.21
# 1206  141012.0  -0.80       SUPP  855.0  10.0   -1.58   -0.01
# 1172  140941.0  -1.48       SUPP  312.0  14.0   -2.19   -0.76
# 3768  141035.0  -0.59       SUPP  312.0  16.0   -1.25    0.07
# 3388  139590.0  -0.87       SUPP  861.0  17.0   -1.47   -0.27

# %% [markdown]
# <img src="pics/banding.png" alt="Drawing" style="width: 400px;" align="left"/>

# %% [markdown]
# **DECISION**: Allocate each 'SUPP' school as either 1, 3 or 5 Banding, based on a simplified version of the government assesment for scoring:
# -   P8 Banding = 1: if P8MEA score >0.5
# -   P8 Banding = 3: if -0.5 < P8MEA score < 0.5
# -   P8 Banding = 5: if P8MEA score < -0.5

# %% [markdown]
# ### <font color='red'>Decisions:</font>
#
# Previously made Decision: a row must have a School_ID (column name: URN) and Progress 8 score (column name: P8MEA) to be included (otherwise it cannot be identified in the data)<br />
#
# i) Replace NaNs for numbers of Boys and Girls with zeroes.<br />
# ii) Replace girls-related fields that have NP with 0 because they are girls-only (checked with % girls / boys column).  Similarly for boys.<br />
# iii) Admissions Policy: change blanks to 'OTHER NON SEL'<br />
# iv) P8 Banding: allocate each 'SUPP' school as either 1, 3 or 5 Banding, based on government scoring<br />
# v)  Remove any remaining column that has non-numerics (NaNs) in them (excluding non-numeric columns) since the data cannot be inferred.<br />

# %% [markdown]
# <a id='7'></a>

# %% [markdown]
# # <font color='blue'>7) Action the decisions made in 6) above, to make data modelable</font>

# %%
df6 = df5.copy()

# %% [markdown]
# ### <font color='green'>i) Replace NaNs for numbers of Boys and Girls with zeroes</font>

# %%
df6['PBPUP'] = df6['PBPUP'].fillna('0%')
df6['P8PUP_BOYS'] = df6['P8PUP_BOYS'].fillna('0%')
df6['ATT8SCR_BOYS'] = df6['ATT8SCR_BOYS'].fillna('0%')
df6['P8MEA_BOYS'] = df6['P8MEA_BOYS'].fillna('0%')

df6['ATT8SCR_GIRLS'] = df6['ATT8SCR_GIRLS'].fillna('0%')
df6['P8MEA_GIRLS'] = df6['P8MEA_GIRLS'].fillna('0%')
df6['P8PUP_GIRLS'] = df6['P8PUP_GIRLS'].fillna('0%')
df6['NUMGIRLS'] = df6['NUMGIRLS'].fillna('0%')
df6['EBACCAPS_GIRLS'] = df6['EBACCAPS_GIRLS'].fillna('0%')

df6['NUMBOYS'] = df6['NUMBOYS'].fillna('0%')

# %% [markdown]
# ### <font color='green'>ii) Replace girls-related fields that have NP with 0 because they are girls-only (checked with % girls / boys column).  Similarly for boys.</font>

# %%
df6[(df6['ATT8SCREBAC_BOYS'] == 'NE') & (df6['EGENDER'] == 'GIRLS')]
# Out:
#       RECTYPE    LEA   ESTAB       URN  \
# 1           1  202.0  4166.0  100050.0
# 7           1  202.0  5401.0  100059.0
# 13          1  203.0  4682.0  100193.0
# 16          1  204.0  4302.0  137442.0
# 17          1  204.0  4641.0  100282.0
# ...       ...    ...     ...       ...
# 4110        1  931.0  4139.0  138490.0
# 4120        1  937.0  5406.0  136595.0
# 5433        1  320.0  4002.0  140957.0
# 5434        1  358.0  4014.0  136965.0
# 5436        1  886.0  5400.0  137250.0
#
#                                         SCHNAME     PCODE  ICLOSE NFTYPE  \
# 1                        Parliament Hill School   NW5 1RL     0.0     CY
# 7     La Sainte Union Catholic Secondary School   NW5 1RP     0.0     VA
# 13                   St Ursula's Convent School  SE10 8HN     0.0     VA
# 16                       Clapton Girls' Academy    E5 0RB     0.0    ACC
# 17              Our Lady's Catholic High School   N16 5AF     0.0     VA
# ...                                         ...       ...     ...    ...
# 4110                       Didcot Girls' School  OX11 7AJ     0.0    ACC
# 4120                          Rugby High School  CV22 7RE     0.0    ACC
# 5433          Eden Girls' School Waltham Forest   E17 5SD     0.0      F
# 5434                       Flixton Girls School   M41 5DR     0.0    ACC
# 5436        Wilmington Grammar School for Girls   DA2 7BB     0.0    ACC
#
#             RELDENOM ADMPOL  ... TAVENT_E_3NG_HI_PTQ_EE  \
# 1     Does not apply   COMP  ...                    8.8
# 7     Roman Catholic   COMP  ...                    8.6
# 13    Roman Catholic   COMP  ...                   10.7
# 16    Does not apply   COMP  ...                    9.2
# 17    Roman Catholic   COMP  ...                    8.3
# ...              ...    ...  ...                    ...
# 4110  Does not apply   COMP  ...                    9.4
# 4120            None    SEL  ...                    9.4
# 5433          Muslim   COMP  ...                   10.6
# 5434            None    MOD  ...                      8
# 5436            None    SEL  ...                    9.4
#
#      TAVENT_E_3NG_FSM6CLA1A_PTQ_EE  TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE  \
# 1                              8.6                             8.4
# 7                              8.3                             8.5
# 13                             9.7                              10
# 16                             8.1                             8.9
# 17                             7.9                               8
# ...                            ...                             ...
# 4110                           6.9                             8.6
# 4120                          SUPP                            SUPP
# 5433                          10.1                             9.6
# 5434                           7.6                             8.1
# 5436                           9.5                             9.3
#
#       TAVENT_G_PTQ_EE  TAVENT_GLO_PTQ_EE TAVENT_GAV_PTQ_EE TAVENT_GHI_PTQ_EE  \
# 1                 8.4                6.9               8.1               8.7
# 7                 8.4                7.7               8.2               8.6
# 13                9.9                  8                 9              10.7
# 16                8.2                5.2               7.7               9.1
# 17                7.4                6.3               7.2               8.1
# ...               ...                ...               ...               ...
# 4110              8.1                6.1               7.4               9.1
# 4120              9.2                 NE              SUPP               9.2
# 5433              9.8               SUPP               9.6              10.6
# 5434              7.8                6.9               7.7                 8
# 5436              9.3                 NE               8.8               9.4
#
#      TAVENT_GFSM6CLA1A_PTQ_EE  TAVENT_GNFSM6CLA1A_PTQ_EE P8_BANDING
# 1                         8.5                        8.3          1
# 7                         8.3                        8.5          1
# 13                        9.7                         10          1
# 16                        7.9                        8.8          1
# 17                        7.3                        7.5          3
# ...                       ...                        ...        ...
# 4110                      6.5                        8.3          1
# 4120                     SUPP                       SUPP          1
# 5433                     10.1                        9.6          1
# 5434                      7.2                        7.9          3
# 5436                      9.5                        9.3          3
#
# [200 rows x 278 columns]

# %%
df_data_issues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278 entries, 365 to 0
# Data columns (total 11 columns):
# column_name           278 non-null object
# # nulls               278 non-null int64
# # "NE"                278 non-null int64
# # "SUPP"              278 non-null int64
# # "NEW"               278 non-null int64
# # "NA"                278 non-null int64
# # "LOWCOV"            278 non-null int64
# # "NP"                278 non-null int64
# total_freq            278 non-null int64
# pct_all_rows          278 non-null int64
# column_description    278 non-null object
# dtypes: int64(9), object(2)
# memory usage: 26.1+ KB

# %%
df_data_issues.head()
# Out:
#             column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 365  LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 256           P8MEA_EAL        0     150      1168        0       0
# 255          TP8ADJ_EAL        0     165      1168        0       0
# 259      P8MEA_EAL_ORIG        0     165      1168        0       0
# 254           P8PUP_EAL        0     149      1168        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows  \
# 365           5       0        2587            82
# 256           0      15        1333            42
# 255           0       0        1333            42
# 259           0       0        1333            42
# 254           0      15        1332            42
#
#                                     column_description
# 365  English Baccalaureate Languages Value Added me...
# 256  Adjusted Progress 8 measure - pupils for whom ...
# 255  Number of pupils for whom English is an additi...
# 259  Unadjusted Progress 8 measure - pupils for who...
# 254  Number of pupils for whom English is an additi...

# %%
df6[(df6['P8MEA_BOYS_ORIG'] == 'NE') & (df6['EGENDER'] == 'MIXED')]
# Out:
#       RECTYPE    LEA   ESTAB       URN  \
# 9           1  203.0  4130.0  100183.0
# 30          1  206.0  4001.0  143659.0
# 355         1  318.0  4021.0  138461.0
# 1211        1  887.0  5445.0  136313.0
# 1508        1  916.0  4012.0  115720.0
# 1908        1  837.0  5404.0  138193.0
# 2018        1  851.0  4002.0  139714.0
# 2464        1  881.0  5461.0  138834.0
# 3808        1  341.0  5403.0  104721.0
#
#                                        SCHNAME     PCODE  ICLOSE NFTYPE  \
# 9                       Plumstead Manor School  SE18 1QF     0.0     CY
# 30       City of London Academy, Highgate Hill   N19 3EU     0.0      F
# 355                          Waldegrave School   TW2 5LH     0.0    ACC
# 1211              The Rochester Grammar School   ME1 3BY     0.0    ACC
# 1508                Barnwood Park Arts College   GL4 3QU     0.0     FD
# 1908                        Avonbourne College   BH7 6NY     0.0    ACC
# 2018                    The Portsmouth Academy   PO1 5PF     0.0     AC
# 2464    Brentwood Ursuline Convent High School  CM14 4EX     0.0    ACC
# 3808  St Hilda's Church of England High School   L17 3AL     0.0     VA
#
#                RELDENOM ADMPOL  ... TAVENT_E_3NG_HI_PTQ_EE  \
# 9        Does not apply   COMP  ...                    9.3
# 30                 None   COMP  ...                    8.3
# 355      Does not apply   COMP  ...                    9.3
# 1211               None    SEL  ...                   10.5
# 1508               None   COMP  ...                    8.4
# 1908               None    MOD  ...                     11
# 2018     Does not apply   COMP  ...                    9.7
# 2464     Roman Catholic   COMP  ...                    9.9
# 3808  Church of England   COMP  ...                      8
#
#      TAVENT_E_3NG_FSM6CLA1A_PTQ_EE  TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE  \
# 9                              7.9                             8.5
# 30                             8.3                             7.9
# 355                            7.5                             9.1
# 1211                           9.9                            10.3
# 1508                           7.3                             7.9
# 1908                           9.2                             9.8
# 2018                             8                             8.4
# 2464                             9                             9.4
# 3808                             7                               8
#
#       TAVENT_G_PTQ_EE  TAVENT_GLO_PTQ_EE TAVENT_GAV_PTQ_EE TAVENT_GHI_PTQ_EE  \
# 9                 7.9                5.3               7.8               9.1
# 30                7.9                7.3                 8                 8
# 355               8.9                6.8               8.6               9.3
# 1211             10.3                 NE               9.1              10.5
# 1508              7.7                6.1               7.7               8.4
# 1908              9.5                7.2               9.4              10.8
# 2018                8                6.9               7.7               9.5
# 2464              9.4                7.6                 9               9.9
# 3808              7.4                  5               7.1               7.8
#
#      TAVENT_GFSM6CLA1A_PTQ_EE  TAVENT_GNFSM6CLA1A_PTQ_EE P8_BANDING
# 9                         7.6                        8.2          3
# 30                          8                        7.6          3
# 355                       7.5                        9.1          1
# 1211                      9.9                       10.3          1
# 1508                      7.3                        7.9          2
# 1908                      9.1                        9.7          2
# 2018                      7.7                        8.4          3
# 2464                        9                        9.4          1
# 3808                      6.8                        7.8          3
#
# [9 rows x 278 columns]

# %%
df6[df6['P8MEA_BOYS_ORIG'] == 'NE'][['URN', 'PBPUP','TP8ADJ_BOYS', 'ATT8SCROPENG_BOYS']][:10]
# Out:
#          URN PBPUP TP8ADJ_BOYS ATT8SCROPENG_BOYS
# 1   100050.0    0%          NE                NE
# 7   100059.0    0%          NE                NE
# 9   100183.0    0%          NE                NE
# 13  100193.0    0%          NE                NE
# 16  137442.0    0%          NE                NE
# 17  100282.0    0%          NE                NE
# 30  143659.0    0%          NE                NE
# 33  100455.0    0%          NE                NE
# 34  100457.0    0%          NE                NE
# 40  100503.0    0%          NE                NE

# %%
df_item_freq2 = item_freq_in_col(df6,['NE','SUPP', 'NEW', 'NA', 'LOWCOV', 'NP'])
df_item_freq2.head(100)
# Out:
#                     column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 223          LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 160                   P8MEA_EAL        0     150      1168        0       0
# 159                  TP8ADJ_EAL        0     165      1168        0       0
# 161              P8MEA_EAL_ORIG        0     165      1168        0       0
# 158                   P8PUP_EAL        0     149      1168        0       0
# ..                          ...      ...     ...       ...      ...     ...
# 217  SCIVAMEA_NFSM6CLA1A_PTQ_EE        0       4        77        0       0
# 201                PTEBACCAV_94        0      29        52        0       0
# 200          PTEBACC_EAV_PTQ_EE        0      29        52        0       0
# 267      TAVENT_E_3NG_AV_PTQ_EE        0      29        52        0       0
# 273           TAVENT_GAV_PTQ_EE        0      29        52        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 223           5       0        2587            82
# 160           0      15        1333            42
# 159           0       0        1333            42
# 161           0       0        1333            42
# 158           0      15        1332            42
# ..          ...     ...         ...           ...
# 217           0       0          81             3
# 201           0       0          81             3
# 200           0       0          81             3
# 267           0       0          81             3
# 273           0       0          81             3
#
# [100 rows x 10 columns]

# %%
# for girls

girls_NE_cols = [
'NUMGIRLS',
'EBACCAPS_GIRLS',
'ATT8SCR_GIRLS',
'ATT8SCRENG_GIRLS',
'ATT8SCRMAT_GIRLS',
'ATT8SCREBAC_GIRLS',
'ATT8SCROPEN_GIRLS',
'ATT8SCROPENG_GIRLS',
'ATT8SCROPENNG_GIRLS',
'P8PUP_GIRLS',
'TP8ADJ_GIRLS',
'P8MEA_GIRLS',
'P8MEA_GIRLS_ORIG',
'PGEBACC_E_PTQ_EE',
'PGEBACC_94',
'PGEBACC_95',
'PGL2BASICS_94',
'PGL2BASICS_95']

# %%
# for boys...

boys_NE_cols = [
'NUMBOYS',
'PBPUP',
'ATT8SCR_BOYS',
'ATT8SCRENG_BOYS',
'ATT8SCRMAT_BOYS',
'ATT8SCREBAC_BOYS',
'ATT8SCROPEN_BOYS',
'ATT8SCROPENG_BOYS',
'ATT8SCROPENNG_BOYS',
'P8PUP_BOYS',
'TP8ADJ_BOYS',
'P8MEA_BOYS',
'P8MEA_BOYS_ORIG',
'PBEBACC_E_PTQ_EE',
'PBEBACC_94',
'PBEBACC_95',
'PBL2BASICS_94',
'PBL2BASICS_95']

# %%
boys_NE_cols
# Out:
# ['NUMBOYS',
#  'PBPUP',
#  'ATT8SCR_BOYS',
#  'ATT8SCRENG_BOYS',
#  'ATT8SCRMAT_BOYS',
#  'ATT8SCREBAC_BOYS',
#  'ATT8SCROPEN_BOYS',
#  'ATT8SCROPENG_BOYS',
#  'ATT8SCROPENNG_BOYS',
#  'P8PUP_BOYS',
#  'TP8ADJ_BOYS',
#  'P8MEA_BOYS',
#  'P8MEA_BOYS_ORIG',
#  'PBEBACC_E_PTQ_EE',
#  'PBEBACC_94',
#  'PBEBACC_95',
#  'PBL2BASICS_94',
#  'PBL2BASICS_95']

# %%
# define a function to replace vals in columns in a dataframe with specific value

def replace_vals(df, list_cols, word, val):
    '''Replaces values of 'word' in a list of columns (list_cols) in a df with val
    Notes:
    1) Will return just the original value for non-word values in the column
    2) List_cols must be a list
    '''
    for col in list_cols:
        df[col] = df[col].apply(lambda x: val if x == word else x)

# %%
# run the above function

replace_vals(df6, boys_NE_cols,'NE',0)
replace_vals(df6, girls_NE_cols, 'NE', 0)

# %%
df6[df6['P8PUP_BOYS'] == 'SUPP'].loc[:,['URN', 'EGENDER', 'PBPUP']]
# Out:
#            URN EGENDER PBPUP
# 52    100741.0   GIRLS    1%
# 184   102782.0   GIRLS    0%
# 365   103013.0   GIRLS    1%
# 1172  140941.0   MIXED   86%
# 1206  141012.0   MIXED   80%
# 1215  137498.0   MIXED   50%
# 1239  142863.0   MIXED   87%
# 1468  130555.0   MIXED   75%
# 2309  137259.0   GIRLS    1%
# 2398  141749.0   MIXED   92%
# 3353  138229.0   MIXED   81%
# 3360  139773.0   MIXED   63%
# 3372  142130.0   MIXED   97%
# 3387  138256.0   MIXED   94%
# 3405  139661.0   MIXED   52%
# 3406  142124.0   MIXED   88%
# 3421  139895.0   MIXED   70%
# 3452  136594.0    BOYS   98%
# 3456  112378.0   MIXED   55%
# 3718  142905.0   MIXED   82%
# 5432  137935.0   GIRLS    1%

# %%
df_item_freq2 = item_freq_in_col(df6,['NE','SUPP', 'NEW', 'NA', 'LOWCOV', 'NP'])
df_item_freq2[:100]
# Out:
#                column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 223     LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 159             TP8ADJ_EAL        0     165      1168        0       0
# 160              P8MEA_EAL        0     150      1168        0       0
# 161         P8MEA_EAL_ORIG        0     165      1168        0       0
# 158              P8PUP_EAL        0     149      1168        0       0
# ..                     ...      ...     ...       ...      ...     ...
# 113  P8MEA_NFSM6CLA1A_ORIG        0       0        74        0       0
# 125    P8MEAMAT_NFSM6CLA1A        0       0        74        0       0
# 111      TP8ADJ_NFSM6CLA1A        0       0        74        0       0
# 110       P8PUP_NFSM6CLA1A        0       0        74        0       0
# 123    P8MEAENG_NFSM6CLA1A        0       0        74        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 223           5       0        2587            82
# 159           0       0        1333            42
# 160           0      15        1333            42
# 161           0       0        1333            42
# 158           0      15        1332            42
# ..          ...     ...         ...           ...
# 113           0       0          74             2
# 125           0       0          74             2
# 111           0       0          74             2
# 110           0       0          74             2
# 123           0       0          74             2
#
# [100 rows x 10 columns]

# %% [markdown]
# ### <font color='green'>iii) Admissions Policy: change blanks to 'OTHER NON SEL'</font>

# %%
# replace 'ADMPOL' NANs with 'OTHER NON SEL' for 2017 and 'COMP' for pre-2017

df6['ADMPOL_2017'] = df6['ADMPOL_2017'].fillna('OTHER NON SEL')
df6['ADMPOL'] = df6['ADMPOL'].fillna('COMP')

# %% [markdown]
# ### <font color='green'>iv) P8 Banding: allocate each 'SUPP' school as either 1, 3 or 5 Banding, based on government scoring</font>

# %%
# write a function for working out which Progress 8 (P8) Banding a school should be:

def sort_p8_band(x):
    if x < -0.5:
        try:
            return 5
        except:
            return np.nan
    elif x <0.5:
        try:
            return 3
        except:
            return np.nan
    elif x >= 0.5:
        try:
            return 1
        except:
            return np.nan
    else:
        return np.nan

# %%
# apply the function above to the main DataFrame

df6['P8_BANDING'] = df6[['P8MEA', 'P8_BANDING']].apply(lambda x: sort_p8_band(x[0]) if x[1]=='SUPP' else x[1], axis=1)
df6.head(3)
# Out:
#    RECTYPE    LEA   ESTAB       URN                 SCHNAME    PCODE  ICLOSE  \
# 0        1  202.0  4104.0  100049.0       Haverstock School  NW3 2BQ     0.0
# 1        1  202.0  4166.0  100050.0  Parliament Hill School  NW5 1RL     0.0
# 3        1  202.0  4196.0  100051.0      Regent High School  NW1 1RX     0.0
#
#   NFTYPE        RELDENOM ADMPOL  ... TAVENT_E_3NG_HI_PTQ_EE  \
# 0     CY  Does not apply   COMP  ...                    7.7
# 1     CY  Does not apply   COMP  ...                    8.8
# 3     CY  Does not apply   COMP  ...                    8.3
#
#   TAVENT_E_3NG_FSM6CLA1A_PTQ_EE  TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE  \
# 0                           7.2                             7.4
# 1                           8.6                             8.4
# 3                           7.8                             7.9
#
#    TAVENT_G_PTQ_EE  TAVENT_GLO_PTQ_EE TAVENT_GAV_PTQ_EE TAVENT_GHI_PTQ_EE  \
# 0              7.1                6.3               6.9               7.7
# 1              8.4                6.9               8.1               8.7
# 3              7.2                6.4                 7                 8
#
#   TAVENT_GFSM6CLA1A_PTQ_EE  TAVENT_GNFSM6CLA1A_PTQ_EE P8_BANDING
# 0                        7                        7.3          3
# 1                      8.5                        8.3          1
# 3                      7.2                        7.2          4
#
# [3 rows x 278 columns]

# %%
# check that function has worked correctly
df6['P8_BANDING'].astype(int).value_counts()
# Out:
# 3    1196
# 4     594
# 2     512
# 5     445
# 1     418
# Name: P8_BANDING, dtype: int64

# %%
# check that function has worked correctly

df6[['P8MEA', 'P8_BANDING']].head(3)
# Out:
#    P8MEA P8_BANDING
# 0  -0.10          3
# 1   0.65          1
# 3  -0.26          4

# %%
df7 = df6.copy()

# %% [markdown]
# ### <font color='green'>v) Any column that has any non-numerics remaining in it is removed</font>

# %%
df_item_freq3 = item_freq_in_col(df7,['NE','SUPP', 'NEW', 'NA', 'LOWCOV', 'NP'])
df_item_freq3.head(100)
# Out:
#                column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 223     LANVAMEA_LO_PTQ_EE        0     752      1830        0       0
# 161         P8MEA_EAL_ORIG        0     165      1168        0       0
# 160              P8MEA_EAL        0     150      1168        0       0
# 159             TP8ADJ_EAL        0     165      1168        0       0
# 158              P8PUP_EAL        0     149      1168        0       0
# ..                     ...      ...     ...       ...      ...     ...
# 125    P8MEAMAT_NFSM6CLA1A        0       0        74        0       0
# 113  P8MEA_NFSM6CLA1A_ORIG        0       0        74        0       0
# 112       P8MEA_NFSM6CLA1A        0       0        74        0       0
# 111      TP8ADJ_NFSM6CLA1A        0       0        74        0       0
# 123    P8MEAENG_NFSM6CLA1A        0       0        74        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 223           5       0        2587            82
# 161           0       0        1333            42
# 160           0      15        1333            42
# 159           0       0        1333            42
# 158           0      15        1332            42
# ..          ...     ...         ...           ...
# 125           0       0          74             2
# 113           0       0          74             2
# 112           0       0          74             2
# 111           0       0          74             2
# 123           0       0          74             2
#
# [100 rows x 10 columns]

# %%
#Pct_GCSEpup_Eng_addnl_lang

df_item_freq3.loc[df_item_freq3['column_name'] == 'PTEALGRP2']
# Out:
#    column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  # "LOWCOV"  \
# 26   PTEALGRP2        0       0         0        0       0           0
#
#     # "NP"  total_freq  pct_all_rows
# 26      15          15             0

# %%
# columns that will remain
df_item_freq3[df_item_freq3['total_freq'] == 0]
# Out:
#              column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 265  TAVENT_E_3NG_PTQ_EE        0       0         0        0       0
# 264        PTtripleSci_E        0       0         0        0       0
# 271      TAVENT_G_PTQ_EE        0       0         0        0       0
# 242             PT5EM_94        0       0         0        0       0
# 243          PT5EM_94_18        0       0         0        0       0
# ..                   ...      ...     ...       ...      ...     ...
# 48              P8MEAENG        0       0         0        0       0
# 47            P8MEA_ORIG        0       0         0        0       0
# 46               P8CIUPP        0       0         0        0       0
# 45               P8CILOW        0       0         0        0       0
# 277           P8_BANDING        0       0         0        0       0
#
#      # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 265           0       0           0             0
# 264           0       0           0             0
# 271           0       0           0             0
# 242           0       0           0             0
# 243           0       0           0             0
# ..          ...     ...         ...           ...
# 48            0       0           0             0
# 47            0       0           0             0
# 46            0       0           0             0
# 45            0       0           0             0
# 277           0       0           0             0
#
# [74 rows x 10 columns]

# %%
# create list of all columns to be dropped (because they contain non-numeric values)

drop_cols = []
for row in range(0, len(df_item_freq3[df_item_freq3['total_freq'] >0])):
    drop_cols.append(df_item_freq3.values[row][0])

print(drop_cols)
print(len(drop_cols))
# Out:
# ['LANVAMEA_LO_PTQ_EE', 'P8MEA_EAL_ORIG', 'P8MEA_EAL', 'TP8ADJ_EAL', 'P8PUP_EAL', 'EBACCAPS_EAL', 'ATT8SCROPEN_EAL', 'PTL2BASICSEAL_94', 'PTL2BASICSEAL_95', 'ATT8SCR_EAL', 'ATT8SCRENG_EAL', 'ATT8SCRMAT_EAL', 'ATT8SCREBAC_EAL', 'PTEBACCEAL_95', 'ATT8SCROPENG_EAL', 'ATT8SCROPENNG_EAL', 'PTEBACCEAL_94', 'PTEBACC_EEAL_PTQ_EE', 'LANVAMEA_FSM6CLA1A_PTQ_EE', 'HUMVAMEA_LO_PTQ_EE', 'LANVAMEA_AV_PTQ_EE', 'SCIVAMEA_LO_PTQ_EE', 'PTBASICSLO_95', 'PTBASICSLO_94', 'EBACCAPS_LO', 'P8MEA_LO', 'TP8ADJ_LO', 'TEBACC_ELO_PTQ_EE', 'PTEBACCLO_95', 'PTEBACCLO_94', 'TAVENT_GLO_PTQ_EE', 'ATT8SCR_LO', 'P8PUP_LO', 'TAVENT_E_3NG_LO_PTQ_EE', 'PTEBACC_ELO_PTQ_EE', 'P8MEA_LO_ORIG', 'LANVAMEA_HI_PTQ_EE', 'LANVAMEA_NFSM6CLA1A_PTQ_EE', 'HUMVAMEA_FSM6CLA1A_PTQ_EE', 'LANVAMEA_PTQ_EE', 'HUMVAMEA_AV_PTQ_EE', 'SCIVAMEA_FSM6CLA1A_PTQ_EE', 'HUMVAMEA_NFSM6CLA1A_PTQ_EE', 'TEBACLAN_95', 'LANVACOV_PTQ_EE', 'PTEBACLAN_95', 'PTEBACLAN91', 'PTEBACLAN_94', 'TEBACLAN_94', 'SCIVAMEA_AV_PTQ_EE', 'DIFFN_P8MEA', 'P8MEAOPEN_FSM6CLA1A', 'P8MEAEBAC_FSM6CLA1A', 'TP8ADJ_FSM6CLA1A', 'P8MEA_FSM6CLA1A', 'P8MEA_FSM6CLA1A_ORIG', 'P8MEAMAT_FSM6CLA1A', 'P8MEAENG_FSM6CLA1A', 'P8PUP_FSM6CLA1A', 'P8MEAEBAC_NFSM6CLA1A', 'EBACCAPS_AV', 'SCIVAMEA_NFSM6CLA1A_PTQ_EE', 'PTEBACCAV_95', 'PTEBACCAV_94', 'PTEBACC_EAV_PTQ_EE', 'TEBACC_EAV_PTQ_EE', 'TAVENT_GAV_PTQ_EE', 'TAVENT_E_3NG_AV_PTQ_EE', 'P8MEA_AV_ORIG', 'P8MEA_AV', 'TP8ADJ_AV', 'P8PUP_AV', 'ATT8SCR_AV', 'PTBASICSAV_94', 'PTBASICSAV_95', 'ATT8SCREBAC_NFSM6CLA1A', 'HUMVAMEA_HI_PTQ_EE', 'PTFSM6CLA1ABASICS_95', 'PTEBACC_94_FSM6CLA1A', 'PTEBACC_EFSM6CLA1A_PTQ_EE', 'TAVENT_GFSM6CLA1A_PTQ_EE', 'TAVENT_E_3NG_FSM6CLA1A_PTQ_EE', 'EBACCAPS_FSM6CLA1A', 'DIFFN_ATT8', 'ATT8SCROPENNG_FSM6CLA1A', 'ATT8SCROPENG_FSM6CLA1A', 'ATT8SCROPEN_FSM6CLA1A', 'ATT8SCREBAC_FSM6CLA1A', 'ATT8SCRMAT_FSM6CLA1A', 'ATT8SCRENG_FSM6CLA1A', 'ATT8SCR_FSM6CLA1A', 'PTEBACC_95_FSM6CLA1A', 'PTFSM6CLA1ABASICS_94', 'P8MEAOPEN_NFSM6CLA1A', 'P8PUP_NFSM6CLA1A', 'P8MEAMAT_NFSM6CLA1A', 'P8MEA_NFSM6CLA1A_ORIG', 'P8MEA_NFSM6CLA1A', 'TP8ADJ_NFSM6CLA1A', 'P8MEAENG_NFSM6CLA1A', 'PTEBACC_95_NFSM6CLA1A', 'TAVENT_GNFSM6CLA1A_PTQ_EE', 'TAVENT_E_3NG_NFSM6CLA1A_PTQ_EE', 'ATT8SCROPENNG_NFSM6CLA1A', 'EBACCAPS_NFSM6CLA1A', 'PTEBACC_94_NFSM6CLA1A', 'PTNOTFSM6CLA1ABASICS_95', 'ATT8SCROPENG_NFSM6CLA1A', 'ATT8SCROPEN_NFSM6CLA1A', 'ATT8SCR_NFSM6CLA1A', 'ATT8SCRMAT_NFSM6CLA1A', 'ATT8SCRENG_NFSM6CLA1A', 'PTEBACC_ENFSM6CLA1A_PTQ_EE', 'PTNOTFSM6CLA1ABASICS_94', 'SCIVAMEA_HI_PTQ_EE', 'HUMVAMEA_PTQ_EE', 'TEBACHUM_95', 'TP8ADJ_HI', 'PTEBACHUM91', 'PTBASICSHI_95', 'EBACCAPS_HI', 'PTEBACCHI_94', 'TAVENT_E_3NG_HI_PTQ_EE', 'TAVENT_GHI_PTQ_EE', 'HUMVACOV_PTQ_EE', 'PTEBACCHI_95', 'PTEBACC_EHI_PTQ_EE', 'PTEBACHUM_95', 'TEBACC_EHI_PTQ_EE', 'PTEBACHUM_94', 'TEBACHUM_94', 'P8MEA_HI_ORIG', 'P8MEA_HI', 'ATT8SCR_HI', 'P8PUP_HI', 'PTBASICSHI_94', 'PTEBACCNMOB_95', 'PTL2BASICSNMOB_95', 'TP8ADJ_NMOB', 'PTL2BASICSNMOB_94', 'TP8ADJ_BOYS', 'P8MEA_GIRLS', 'P8PUP_BOYS', 'TP8ADJ_GIRLS', 'P8PUP_GIRLS', 'EBACCAPS_NMOB', 'P8MEA_BOYS', 'P8MEA_BOYS_ORIG', 'ATT8SCR_NMOB', 'P8MEA_NMOB', 'P8MEA_NMOB_ORIG', 'PTEBACCNMOB_94', 'PTEBACC_ENMOB_PTQ_EE', 'P8MEA_GIRLS_ORIG', 'P8PUP_NMOB', 'ATT8SCR_BOYS', 'ATT8SCRENG_BOYS', 'ATT8SCRMAT_BOYS', 'ATT8SCREBAC_BOYS', 'ATT8SCROPEN_BOYS', 'ATT8SCROPENG_BOYS', 'ATT8SCROPENNG_BOYS', 'ATT8SCROPEN_GIRLS', 'PBEBACC_E_PTQ_EE', 'ATT8SCROPENNG_GIRLS', 'ATT8SCROPENG_GIRLS', 'PBEBACC_95', 'ATT8SCREBAC_GIRLS', 'PGEBACC_94', 'PBL2BASICS_94', 'PGL2BASICS_94', 'PGEBACC_95', 'PBL2BASICS_95', 'ATT8SCRMAT_GIRLS', 'PGL2BASICS_95', 'PGEBACC_E_PTQ_EE', 'ATT8SCRENG_GIRLS', 'ATT8SCR_GIRLS', 'EBACCAPS_GIRLS', 'PBEBACC_94', 'PTEALGRP3', 'PSENAPK4', 'PSENSE4', 'PTNMOB', 'NUMBOYS', 'NUMGIRLS', 'PTEALGRP2', 'TOTPUPS', 'PTEALGRP1', 'PTEBACC_95_17', 'PTEBACC_94_17', 'PTEBAC2SCI_95', 'TEBAC2SCI_94', 'TEBAC2SCI_95', 'PTEBAC2SCI91', 'SCIVAMEA_PTQ_EE', 'SCIVACOV_PTQ_EE', 'PTEBAC2SCI_94', 'ATT8SCROPENG_NMOB', 'ATT8SCROPENNG_NMOB', 'ATT8SCRENG_NMOB', 'ATT8SCRMAT_NMOB', 'ATT8SCREBAC_NMOB', 'ATT8SCROPEN_NMOB']
# 204

# %%
len(df7.columns)
# Out:
# 278

# %%
# drop the above columns

df8 = df7.drop(drop_cols, axis=1)
len(df8.columns)
# Out:
# 74

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3165 entries, 0 to 5580
# Data columns (total 74 columns):
# RECTYPE                3165 non-null int64
# LEA                    3165 non-null float64
# ESTAB                  3165 non-null float64
# URN                    3165 non-null float64
# SCHNAME                3165 non-null object
# PCODE                  3165 non-null object
# ICLOSE                 3165 non-null float64
# NFTYPE                 3165 non-null object
# RELDENOM               3165 non-null object
# ADMPOL                 3165 non-null object
# ADMPOL_2017            3165 non-null object
# EGENDER                3165 non-null object
# FEEDER                 3165 non-null float64
# TABKS2                 3165 non-null float64
# TAB1618                3165 non-null float64
# TPUP                   3165 non-null float64
# PBPUP                  3165 non-null object
# KS2APS                 3165 non-null object
# PTPRIORLO              3165 non-null object
# PTPRIORAV              3165 non-null object
# PTPRIORHI              3165 non-null object
# PTFSM6CLA1A            3165 non-null object
# PTNOTFSM6CLA1A         3165 non-null object
# ATT8SCR                3165 non-null object
# ATT8SCRENG             3165 non-null object
# ATT8SCRMAT             3165 non-null object
# ATT8SCREBAC            3165 non-null object
# ATT8SCROPEN            3165 non-null object
# ATT8SCROPENG           3165 non-null object
# ATT8SCROPENNG          3165 non-null object
# AVGEBACFILL            3165 non-null object
# AVGOPENFILL            3165 non-null object
# P8PUP                  3165 non-null object
# TP8ADJ                 3165 non-null object
# P8MEACOV               3165 non-null object
# P8MEA                  3165 non-null float64
# P8CILOW                3165 non-null object
# P8CIUPP                3165 non-null object
# P8MEA_ORIG             3165 non-null object
# P8MEAENG               3165 non-null object
# P8MEAMAT               3165 non-null object
# P8MEAEBAC              3165 non-null object
# P8MEAOPEN              3165 non-null object
# PTL2BASICS_94          3165 non-null object
# PTL2BASICS_95          3165 non-null object
# TOTEBACCAPS            3165 non-null object
# EBACCAPS               3165 non-null object
# PTEBACC_E_PTQ_EE       3165 non-null object
# PTEBACC_94             3165 non-null object
# PTEBACC_95             3165 non-null object
# PTEBACENG_E_PTQ_EE     3165 non-null object
# PTEBACMAT_E_PTQ_EE     3165 non-null object
# PTEBAC2SCI_E_PTQ_EE    3165 non-null object
# PTEBACHUM_E_PTQ_EE     3165 non-null object
# PTEBACLAN_E_PTQ_EE     3165 non-null object
# PTEBACENG_94           3165 non-null object
# PTEBACENG_95           3165 non-null object
# PTEBACMAT_94           3165 non-null object
# PTEBACMAT_95           3165 non-null object
# TEBACENG_94            3165 non-null object
# TEBACENG_95            3165 non-null object
# TEBACMAT_94            3165 non-null object
# TEBACMAT_95            3165 non-null object
# PTEBACC91              3165 non-null object
# PTEBACENG91            3165 non-null object
# PTEBACMAT91            3165 non-null object
# PT5EM_94               3165 non-null object
# PT5EM_94_18            3165 non-null object
# PTANYQ_PTQ_EE          3165 non-null object
# PTmultiLan_E           3165 non-null object
# PTtripleSci_E          3165 non-null object
# TAVENT_E_3NG_PTQ_EE    3165 non-null object
# TAVENT_G_PTQ_EE        3165 non-null object
# P8_BANDING             3165 non-null object
# dtypes: float64(9), int64(1), object(64)
# memory usage: 1.8+ MB

# %%
# check that all columns now have no non-numeric fields

df_item_freq4 = item_freq_in_col(df8,['NE','SUPP', 'NEW', 'NA', 'LOWCOV', 'NP'])
df_item_freq4.head()
# Out:
#             column_name  # nulls  # "NE"  # "SUPP"  # "NEW"  # "NA"  \
# 0               RECTYPE        0       0         0        0       0
# 55         PTEBACENG_94        0       0         0        0       0
# 53   PTEBACHUM_E_PTQ_EE        0       0         0        0       0
# 52  PTEBAC2SCI_E_PTQ_EE        0       0         0        0       0
# 51   PTEBACMAT_E_PTQ_EE        0       0         0        0       0
#
#     # "LOWCOV"  # "NP"  total_freq  pct_all_rows
# 0            0       0           0             0
# 55           0       0           0             0
# 53           0       0           0             0
# 52           0       0           0             0
# 51           0       0           0             0

# %% [markdown]
# <a id='8'></a>

# %% [markdown]
# # <font color='blue'>8) Convert all relevant columns to floats</blue>

# %% [markdown]
# ### <font color='green'>a) Display the dtypes of all the rows</blue>

# %%
pd.set_option('display.max_rows', 278)
df8.dtypes
# Out:
# RECTYPE                  int64
# LEA                    float64
# ESTAB                  float64
# URN                    float64
# SCHNAME                 object
# PCODE                   object
# ICLOSE                 float64
# NFTYPE                  object
# RELDENOM                object
# ADMPOL                  object
# ADMPOL_2017             object
# EGENDER                 object
# FEEDER                 float64
# TABKS2                 float64
# TAB1618                float64
# TPUP                   float64
# PBPUP                   object
# KS2APS                  object
# PTPRIORLO               object
# PTPRIORAV               object
# PTPRIORHI               object
# PTFSM6CLA1A             object
# PTNOTFSM6CLA1A          object
# ATT8SCR                 object
# ATT8SCRENG              object
# ATT8SCRMAT              object
# ATT8SCREBAC             object
# ATT8SCROPEN             object
# ATT8SCROPENG            object
# ATT8SCROPENNG           object
# AVGEBACFILL             object
# AVGOPENFILL             object
# P8PUP                   object
# TP8ADJ                  object
# P8MEACOV                object
# P8MEA                  float64
# P8CILOW                 object
# P8CIUPP                 object
# P8MEA_ORIG              object
# P8MEAENG                object
# P8MEAMAT                object
# P8MEAEBAC               object
# P8MEAOPEN               object
# PTL2BASICS_94           object
# PTL2BASICS_95           object
# TOTEBACCAPS             object
# EBACCAPS                object
# PTEBACC_E_PTQ_EE        object
# PTEBACC_94              object
# PTEBACC_95              object
# PTEBACENG_E_PTQ_EE      object
# PTEBACMAT_E_PTQ_EE      object
# PTEBAC2SCI_E_PTQ_EE     object
# PTEBACHUM_E_PTQ_EE      object
# PTEBACLAN_E_PTQ_EE      object
# PTEBACENG_94            object
# PTEBACENG_95            object
# PTEBACMAT_94            object
# PTEBACMAT_95            object
# TEBACENG_94             object
# TEBACENG_95             object
# TEBACMAT_94             object
# TEBACMAT_95             object
# PTEBACC91               object
# PTEBACENG91             object
# PTEBACMAT91             object
# PT5EM_94                object
# PT5EM_94_18             object
# PTANYQ_PTQ_EE           object
# PTmultiLan_E            object
# PTtripleSci_E           object
# TAVENT_E_3NG_PTQ_EE     object
# TAVENT_G_PTQ_EE         object
# P8_BANDING              object
# dtype: object

# %%
df8.get_dtype_counts()
# Out:
# /Users/jacktyler-whittle/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   """Entry point for launching an IPython kernel.
# int64       1
# float64     9
# object     64
# dtype: int64

# %% [markdown]
# ### <font color='green'>b) Convert columns to floats</blue>
#
# Output of this section: dataset with columns all formatted appropriately

# %%
list(df8.columns)
# Out:
# ['RECTYPE',
#  'LEA',
#  'ESTAB',
#  'URN',
#  'SCHNAME',
#  'PCODE',
#  'ICLOSE',
#  'NFTYPE',
#  'RELDENOM',
#  'ADMPOL',
#  'ADMPOL_2017',
#  'EGENDER',
#  'FEEDER',
#  'TABKS2',
#  'TAB1618',
#  'TPUP',
#  'PBPUP',
#  'KS2APS',
#  'PTPRIORLO',
#  'PTPRIORAV',
#  'PTPRIORHI',
#  'PTFSM6CLA1A',
#  'PTNOTFSM6CLA1A',
#  'ATT8SCR',
#  'ATT8SCRENG',
#  'ATT8SCRMAT',
#  'ATT8SCREBAC',
#  'ATT8SCROPEN',
#  'ATT8SCROPENG',
#  'ATT8SCROPENNG',
#  'AVGEBACFILL',
#  'AVGOPENFILL',
#  'P8PUP',
#  'TP8ADJ',
#  'P8MEACOV',
#  'P8MEA',
#  'P8CILOW',
#  'P8CIUPP',
#  'P8MEA_ORIG',
#  'P8MEAENG',
#  'P8MEAMAT',
#  'P8MEAEBAC',
#  'P8MEAOPEN',
#  'PTL2BASICS_94',
#  'PTL2BASICS_95',
#  'TOTEBACCAPS',
#  'EBACCAPS',
#  'PTEBACC_E_PTQ_EE',
#  'PTEBACC_94',
#  'PTEBACC_95',
#  'PTEBACENG_E_PTQ_EE',
#  'PTEBACMAT_E_PTQ_EE',
#  'PTEBAC2SCI_E_PTQ_EE',
#  'PTEBACHUM_E_PTQ_EE',
#  'PTEBACLAN_E_PTQ_EE',
#  'PTEBACENG_94',
#  'PTEBACENG_95',
#  'PTEBACMAT_94',
#  'PTEBACMAT_95',
#  'TEBACENG_94',
#  'TEBACENG_95',
#  'TEBACMAT_94',
#  'TEBACMAT_95',
#  'PTEBACC91',
#  'PTEBACENG91',
#  'PTEBACMAT91',
#  'PT5EM_94',
#  'PT5EM_94_18',
#  'PTANYQ_PTQ_EE',
#  'PTmultiLan_E',
#  'PTtripleSci_E',
#  'TAVENT_E_3NG_PTQ_EE',
#  'TAVENT_G_PTQ_EE',
#  'P8_BANDING']

# %%
# Split out DataFrame into two files: one with columns to convert to floats (df9_to_convert), and the
# other consisting of data already formatted correctly (df9_text)

df9_to_convert = df8.loc[:,'FEEDER':]
df9_text = df8.loc[:,:'EGENDER']
df9_to_convert['URN'] = df7['URN']
df9_to_convert.head()
# Out:
#    FEEDER  TABKS2  TAB1618   TPUP PBPUP KS2APS PTPRIORLO PTPRIORAV PTPRIORHI  \
# 0     0.0     0.0      1.0  197.0   58%   28.1       12%       56%       32%
# 1     1.0     0.0      1.0  168.0    0%   29.5        8%       40%       52%
# 3     0.0     0.0      1.0  133.0   50%   27.4       19%       51%       30%
# 4     0.0     0.0      1.0  184.0   56%     28       19%       44%       37%
# 5     1.0     0.0      1.0  161.0   70%   28.9       11%       46%       43%
#
#   PTFSM6CLA1A  ... PTEBACMAT91 PT5EM_94 PT5EM_94_18 PTANYQ_PTQ_EE  \
# 0         61%  ...         98%      57%         57%           99%
# 1         45%  ...         99%      77%         77%          100%
# 3         68%  ...         94%      42%         42%           99%
# 4         49%  ...         96%      51%         51%           98%
# 5         52%  ...         96%      59%         59%           99%
#
#   PTmultiLan_E PTtripleSci_E TAVENT_E_3NG_PTQ_EE TAVENT_G_PTQ_EE P8_BANDING  \
# 0           5%           17%                 7.3             7.1          3
# 1           8%           33%                 8.5             8.4          1
# 3           2%           20%                 7.8             7.2          4
# 4           9%           22%                 9.2             8.4          3
# 5           4%           24%                 7.8             7.7          3
#
#         URN
# 0  100049.0
# 1  100050.0
# 3  100051.0
# 4  100052.0
# 5  100053.0
#
# [5 rows x 63 columns]

# %%
# write function to change number formatted as a string and as 'xx%' into a float

def change_string(x): 
    if type(x) == str: 
        try:
            return float(x.replace("%",""))
        except:
            return x
    else:
        return x

# %%
# convert columns to numbers by removing % sign and converting to float

for col in df9_to_convert.columns:
    df9_to_convert[col] = df9_to_convert[col].apply(change_string)

# %%
df9_to_convert.head(3)
# Out:
#    FEEDER  TABKS2  TAB1618   TPUP  PBPUP  KS2APS  PTPRIORLO  PTPRIORAV  \
# 0     0.0     0.0      1.0  197.0   58.0    28.1       12.0       56.0
# 1     1.0     0.0      1.0  168.0    0.0    29.5        8.0       40.0
# 3     0.0     0.0      1.0  133.0   50.0    27.4       19.0       51.0
#
#    PTPRIORHI  PTFSM6CLA1A  ...  PTEBACMAT91  PT5EM_94  PT5EM_94_18  \
# 0       32.0         61.0  ...         98.0      57.0         57.0
# 1       52.0         45.0  ...         99.0      77.0         77.0
# 3       30.0         68.0  ...         94.0      42.0         42.0
#
#    PTANYQ_PTQ_EE  PTmultiLan_E  PTtripleSci_E  TAVENT_E_3NG_PTQ_EE  \
# 0           99.0           5.0           17.0                  7.3
# 1          100.0           8.0           33.0                  8.5
# 3           99.0           2.0           20.0                  7.8
#
#    TAVENT_G_PTQ_EE  P8_BANDING       URN
# 0              7.1         3.0  100049.0
# 1              8.4         1.0  100050.0
# 3              7.2         4.0  100051.0
#
# [3 rows x 63 columns]

# %%
# check data types of columns

df9_to_convert.get_dtype_counts()
# Out:
# /Users/jacktyler-whittle/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   This is separate from the ipykernel package so we can avoid doing imports until
# float64    63
# dtype: int64

# %% [markdown]
# ### <font color='green'>c) Finalise Datasets</font>

# %%
df_final_base_feat = pd.merge(df9_text, df9_to_convert, on='URN', how='left', left_index=True)
df_final_base_feat.head(10)
# Out:
#     RECTYPE    LEA   ESTAB       URN  \
# 0         1  202.0  4104.0  100049.0
# 1         1  202.0  4166.0  100050.0
# 3         1  202.0  4196.0  100051.0
# 4         1  202.0  4275.0  100052.0
# 5         1  202.0  4285.0  100053.0
# 6         1  202.0  4652.0  100055.0
# 7         1  202.0  5401.0  100059.0
# 8         1  203.0  4001.0  138245.0
# 9         1  203.0  4130.0  100183.0
# 10        1  203.0  4243.0  137473.0
#
#                                       SCHNAME     PCODE  ICLOSE NFTYPE  \
# 0                           Haverstock School   NW3 2BQ     0.0     CY
# 1                      Parliament Hill School   NW5 1RL     0.0     CY
# 3                          Regent High School   NW1 1RX     0.0     CY
# 4                            Hampstead School   NW2 3RT     0.0     CY
# 5                      Acland Burghley School   NW5 1UJ     0.0     CY
# 6           Maria Fidelis Catholic School FCJ   NW1 1LY     0.0     VA
# 7   La Sainte Union Catholic Secondary School   NW5 1RP     0.0     VA
# 8                   Ark Greenwich Free School  SE18 4LH     0.0      F
# 9                      Plumstead Manor School  SE18 1QF     0.0     CY
# 10                            Corelli College   SE3 8EP     1.0    ACC
#
#           RELDENOM ADMPOL  ... PTEBACENG91 PTEBACMAT91  PT5EM_94  PT5EM_94_18  \
# 0   Does not apply   COMP  ...        98.0        98.0      57.0         57.0
# 1   Does not apply   COMP  ...        98.0        99.0      77.0         77.0
# 3   Does not apply   COMP  ...        95.0        94.0      42.0         42.0
# 4   Does not apply   COMP  ...        97.0        96.0      51.0         51.0
# 5   Does not apply   COMP  ...        99.0        96.0      59.0         59.0
# 6   Roman Catholic   COMP  ...        99.0        98.0      45.0         45.0
# 7   Roman Catholic   COMP  ...       100.0        99.0      80.0         80.0
# 8             None   COMP  ...       100.0        99.0      60.0         60.0
# 9   Does not apply   COMP  ...        95.0        86.0      45.0         45.0
# 10  Does not apply   COMP  ...        93.0        87.0      30.0         30.0
#
#     PTANYQ_PTQ_EE  PTmultiLan_E  PTtripleSci_E  TAVENT_E_3NG_PTQ_EE  \
# 0            99.0           5.0           17.0                  7.3
# 1           100.0           8.0           33.0                  8.5
# 3            99.0           2.0           20.0                  7.8
# 4            98.0           9.0           22.0                  9.2
# 5            99.0           4.0           24.0                  7.8
# 6           100.0           8.0           25.0                  7.9
# 7           100.0           8.0           28.0                  8.4
# 8           100.0           2.0           66.0                  8.6
# 9            96.0           6.0           16.0                  8.2
# 10           97.0           9.0           16.0                  7.4
#
#     TAVENT_G_PTQ_EE  P8_BANDING
# 0               7.1         3.0
# 1               8.4         1.0
# 3               7.2         4.0
# 4               8.4         3.0
# 5               7.7         3.0
# 6               7.8         4.0
# 7               8.4         1.0
# 8               8.6         2.0
# 9               7.9         3.0
# 10              6.7         5.0
#
# [10 rows x 74 columns]

# %%
df_final_base_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3165 entries, 0 to 5580
# Data columns (total 74 columns):
# RECTYPE                3165 non-null int64
# LEA                    3165 non-null float64
# ESTAB                  3165 non-null float64
# URN                    3165 non-null float64
# SCHNAME                3165 non-null object
# PCODE                  3165 non-null object
# ICLOSE                 3165 non-null float64
# NFTYPE                 3165 non-null object
# RELDENOM               3165 non-null object
# ADMPOL                 3165 non-null object
# ADMPOL_2017            3165 non-null object
# EGENDER                3165 non-null object
# FEEDER                 3165 non-null float64
# TABKS2                 3165 non-null float64
# TAB1618                3165 non-null float64
# TPUP                   3165 non-null float64
# PBPUP                  3165 non-null float64
# KS2APS                 3165 non-null float64
# PTPRIORLO              3165 non-null float64
# PTPRIORAV              3165 non-null float64
# PTPRIORHI              3165 non-null float64
# PTFSM6CLA1A            3165 non-null float64
# PTNOTFSM6CLA1A         3165 non-null float64
# ATT8SCR                3165 non-null float64
# ATT8SCRENG             3165 non-null float64
# ATT8SCRMAT             3165 non-null float64
# ATT8SCREBAC            3165 non-null float64
# ATT8SCROPEN            3165 non-null float64
# ATT8SCROPENG           3165 non-null float64
# ATT8SCROPENNG          3165 non-null float64
# AVGEBACFILL            3165 non-null float64
# AVGOPENFILL            3165 non-null float64
# P8PUP                  3165 non-null float64
# TP8ADJ                 3165 non-null float64
# P8MEACOV               3165 non-null float64
# P8MEA                  3165 non-null float64
# P8CILOW                3165 non-null float64
# P8CIUPP                3165 non-null float64
# P8MEA_ORIG             3165 non-null float64
# P8MEAENG               3165 non-null float64
# P8MEAMAT               3165 non-null float64
# P8MEAEBAC              3165 non-null float64
# P8MEAOPEN              3165 non-null float64
# PTL2BASICS_94          3165 non-null float64
# PTL2BASICS_95          3165 non-null float64
# TOTEBACCAPS            3165 non-null float64
# EBACCAPS               3165 non-null float64
# PTEBACC_E_PTQ_EE       3165 non-null float64
# PTEBACC_94             3165 non-null float64
# PTEBACC_95             3165 non-null float64
# PTEBACENG_E_PTQ_EE     3165 non-null float64
# PTEBACMAT_E_PTQ_EE     3165 non-null float64
# PTEBAC2SCI_E_PTQ_EE    3165 non-null float64
# PTEBACHUM_E_PTQ_EE     3165 non-null float64
# PTEBACLAN_E_PTQ_EE     3165 non-null float64
# PTEBACENG_94           3165 non-null float64
# PTEBACENG_95           3165 non-null float64
# PTEBACMAT_94           3165 non-null float64
# PTEBACMAT_95           3165 non-null float64
# TEBACENG_94            3165 non-null float64
# TEBACENG_95            3165 non-null float64
# TEBACMAT_94            3165 non-null float64
# TEBACMAT_95            3165 non-null float64
# PTEBACC91              3165 non-null float64
# PTEBACENG91            3165 non-null float64
# PTEBACMAT91            3165 non-null float64
# PT5EM_94               3165 non-null float64
# PT5EM_94_18            3165 non-null float64
# PTANYQ_PTQ_EE          3165 non-null float64
# PTmultiLan_E           3165 non-null float64
# PTtripleSci_E          3165 non-null float64
# TAVENT_E_3NG_PTQ_EE    3165 non-null float64
# TAVENT_G_PTQ_EE        3165 non-null float64
# P8_BANDING             3165 non-null float64
# dtypes: float64(66), int64(1), object(7)
# memory usage: 1.8+ MB

# %%
df_final_base_feat.head()
# Out:
#    RECTYPE    LEA   ESTAB       URN                 SCHNAME    PCODE  ICLOSE  \
# 0        1  202.0  4104.0  100049.0       Haverstock School  NW3 2BQ     0.0
# 1        1  202.0  4166.0  100050.0  Parliament Hill School  NW5 1RL     0.0
# 3        1  202.0  4196.0  100051.0      Regent High School  NW1 1RX     0.0
# 4        1  202.0  4275.0  100052.0        Hampstead School  NW2 3RT     0.0
# 5        1  202.0  4285.0  100053.0  Acland Burghley School  NW5 1UJ     0.0
#
#   NFTYPE        RELDENOM ADMPOL  ... PTEBACENG91 PTEBACMAT91  PT5EM_94  \
# 0     CY  Does not apply   COMP  ...        98.0        98.0      57.0
# 1     CY  Does not apply   COMP  ...        98.0        99.0      77.0
# 3     CY  Does not apply   COMP  ...        95.0        94.0      42.0
# 4     CY  Does not apply   COMP  ...        97.0        96.0      51.0
# 5     CY  Does not apply   COMP  ...        99.0        96.0      59.0
#
#    PT5EM_94_18  PTANYQ_PTQ_EE  PTmultiLan_E  PTtripleSci_E  \
# 0         57.0           99.0           5.0           17.0
# 1         77.0          100.0           8.0           33.0
# 3         42.0           99.0           2.0           20.0
# 4         51.0           98.0           9.0           22.0
# 5         59.0           99.0           4.0           24.0
#
#    TAVENT_E_3NG_PTQ_EE  TAVENT_G_PTQ_EE  P8_BANDING
# 0                  7.3              7.1         3.0
# 1                  8.5              8.4         1.0
# 3                  7.8              7.2         4.0
# 4                  9.2              8.4         3.0
# 5                  7.8              7.7         3.0
#
# [5 rows x 74 columns]

# %% [markdown]
# <a id='9'></a>

# %% [markdown]
# # <font color='blue'>9) Export final (base) dataset</blue>

# %%
# EXPORT FILE TO CSV

df_final_base_feat.to_csv('data_files/final_base_feat_gcse_2018.csv')

# %% [markdown]
# END
